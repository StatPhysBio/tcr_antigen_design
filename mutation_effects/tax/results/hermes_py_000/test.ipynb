# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('tax_peptide_kd_1ao7-hermes_py_000-use_mt_structure=0.csv')

plt.scatter(df['neg_delta_log10_Kd'], df['log_proba_mt__minus__log_proba_wt'])
plt.show()

plt.scatter(df['-log10(Kd)'], df['log_proba_mt__minus__log_proba_wt'])
plt.show()

plt.scatter(df['-log10(Kd)'], df['pe_mt'])
plt.show()

plt.scatter(df['-log10(Kd)'], df['log_proba_mt'])
plt.show()

plt.scatter(df['pe_mt'], df['log_proba_mt'])
plt.show()

plt.scatter(df['log_proba_mt'], df['log_proba_mt__minus__log_proba_wt'])
plt.show()
