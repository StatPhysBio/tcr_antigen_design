# %%
# ## DONE!!!

# import pandas as pd

# # Cleaning up and reformatting the input string
# input_text_1 = """AA abbr V1 V2 V3 V4 V5 V6 V7 V8 V9 V10 V11 V12 V13 V14 V15 V16 V17 V18
# Ala A 7.3 -0.368 0.67 297 0 0 0.1 1 0.5 -0.1 -2.89 25 5.1 0.87 1.94 0.89 -1.52 0.3
# Arg R -3.6 -1.03 -2.1 238 4 3 1.91 2.3 0.8 -4.5 -3.3 -7 2 0.85 -19.92 0.88 -2.84 -1.4
# Asn N -5.7 0 -0.6 236 2 3 0.48 2.2 0.8 -1.6 -3.41 -7 0.6 0.09 -9.68 0.89 -2.41 -0.5
# Asp D -2.9 2.06 -1.2 270 1 4 0.78 6.5 -8.2 -2.8 -3.38 2 0.7 0.66 -10.95 0.87 -2.6 -0.6
# Cys C -9.2 4.53 0.38 178 0 0 -1.42 0.1 -6.8 -2.2 -2.49 32 NaN 1.52 -1.24 0.85 -0.29 0.9
# Gln Q -0.3 0.731 -0.22 185 2 3 0.95 2.1 -4.8 -2.5 -3.15 0 1.4 0 -9.38 0.82 -2.05 -0.7
# Glu E -7.1 1.77 -0.76 249 1 4 0.83 6.2 -16.9 -7.5 -2.94 14 1.8 0.67 -10.2 0.84 -2.47 -0.7
# Gly G -1.2 -0.525 0 290 0 0 0.33 1.1 0 -0.5 -3.25 -2 4.1 0.1 2.39 0.92 -1.83 0.3
# His H -2.1 0 0.64 277 1 1 -0.5 2.8 -3.5 0.8 -2.84 -26 1.6 0.87 -10.27 0.83 -1.7 -0.1
# Ile I 6.6 0.791 1.9 284 0 0 -1.13 0.8 13.9 11.8 -1.72 91 9.3 3.15 2.15 0.76 -0.03 0.7
# Leu L 20 1.07 1.9 337 0 0 -1.18 0.8 8.8 10 -1.61 100 10 2.17 2.28 0.73 -0.13 0.5
# Lys K -3.7 0 -0.57 224 2 1 1.4 5.3 0.1 -3.2 -3.31 -26 1.3 1.64 -9.52 0.97 -2.82 -1.8
# Met M 5.6 0.656 2.4 283 0 0 -1.59 0.7 4.8 7.1 -1.84 68 8.7 1.67 -1.48 0.76 0.6 0.4
# Phe F 19.2 1.06 2.3 284 0 0 -2.12 1.4 13.2 13.9 -1.63 100 9.6 2.87 -0.76 0.52 -0.04 0.5
# Pro P 5.1 -2.24 1.2 222 0 0 0.73 0.9 6.1 8 -2.5 25 4.9 2.77 NaN 0.82 -1.34 -0.3
# Ser S -4.1 -0.524 0.01 228 1 2 0.52 1.7 1.2 -3.7 -3.3 -2 3.1 0.07 -5.06 0.96 -1.87 -0.1
# Thr T 0.8 0 0.52 253 1 2 0.07 1.5 2.7 1.5 -2.91 7 3.5 0.07 -4.88 0.92 -1.57 -0.2
# Trp W 16.3 1.16 2.6 282 1 0 -0.51 1.9 14.9 18.1 -1.75 109 9.2 3.77 -5.88 0.2 0.42 0.3
# Tyr Y 5.9 4.91 1.6 344 1 2 -0.21 2.1 6.1 8.2 -2.42 56 8 2.67 -6.11 0.49 -0.87 -0.4
# Val V 3.5 0.401 1.5 293 0 0 -1.27 0.9 2.7 3.3 -2.08 62 8.5 1.87 1.99 0.85 -0.61 0.6
# """
# rows_1 = [line.split() for line in input_text_1.split('\n') if line]
# df_1 = pd.DataFrame(rows_1[1:], columns = rows_1[0])


# input_text_2 = """AA abbr V19 V20 V21 V22 V23 V24 V25 V26 V27 V28 V29 V30 V31 V32 V33 V34 V35
# Ala A 91.5 115 1.28 1 2.87 1.52 2.04 27.8 0.77 121.9 243.2 0.77 5.2 0.025 4.34 17.05 13.7
# Arg R 202 225 2.34 6.13 7.82 1.52 6.24 94.7 3.72 121.4 206.6 2.38 6 0.2 26.66 21.25 77.3
# Asn N 135.2 160 1.6 2.95 4.58 1.52 4.37 60.1 1.98 117.5 207.1 1.45 5 0.1 13.28 34.81 32.7
# Asp D 124.5 150 1.6 2.78 4.74 1.52 3.78 60.6 1.99 121.2 215 1.43 5 0.1 12 19.27 30
# Cys C 117.7 135 1.77 2.43 4.47 1.52 3.41 15.5 1.38 113.7 209.4 1.22 6.1 0.1 35.77 28.84 25
# Gln Q 161.1 180 1.56 3.95 6.11 1.52 3.53 68.7 2.58 118 205.4 1.75 6 0.1 17.56 15.42 42.7
# Glu E 155.1 190 1.56 3.78 5.97 1.52 3.31 68.2 2.63 118.2 213.6 1.77 6 0.1 17.26 20.12 40.2
# Gly G 66.4 75 0 0 2.06 1 1 24.5 0 0 300 0.58 4.2 0.025 0 38.14 3.5
# His H 167.3 195 2.99 4.66 5.23 1.52 5.66 50.7 2.76 118.2 219.9 1.78 6 0.1 21.81 23.07 45.1
# Ile I 168.8 175 4.19 4 4.92 1.9 3.49 22.8 1.83 118.9 217.9 1.56 7 0.19 19.06 16.66 44.4
# Leu L 167.9 170 2.59 4 4.92 1.52 4.45 27.6 2.08 118.1 205.6 1.54 7 0.19 18.78 10.89 44.4
# Lys K 171.3 200 1.89 4.77 6.89 1.52 4.87 103 2.94 122 210.9 2.08 6 0.2 21.29 16.46 61.5
# Met M 170.8 185 2.35 4.43 6.36 1.52 4.8 33.5 2.34 113.1 204 1.8 6.8 0.19 21.64 20.61 45
# Phe F 203.4 210 2.94 5.89 4.62 1.52 6.02 25.5 2.97 118.2 203.7 1.9 7.1 0.39 29.4 16.26 56.1
# Pro P 129.3 145 2.67 2.72 4.11 1.52 4.31 51.5 1.42 81.9 237.4 1.25 6.2 0.17 10.93 23.94 30.7
# Ser S 99.1 115 1.31 1.6 3.97 1.52 2.7 42 1.28 117.9 232 1.08 4.9 0.025 6.35 19.95 18.3
# Thr T 122.1 140 3.03 2.6 4.11 1.73 3.17 45 1.43 117.1 226.7 1.24 5 0.1 11.01 18.92 28.5
# Trp W 237.6 255 3.21 8.08 7.68 1.52 5.9 34.7 3.58 118.4 203.7 2.21 7.6 0.56 42.53 23.36 74.8
# Tyr Y 203.6 230 2.94 6.47 4.73 1.52 6.72 55.2 3.36 110 195.6 2.13 7.1 0.39 31.53 26.49 59.1
# Val V 141.7 155 3.67 3 4.11 1.9 3.17 23.7 1.49 121.7 220.3 1.29 6.4 0.15 13.92 17.06 34.1
# """
# rows_2 = [line.split() for line in input_text_2.split('\n') if line]
# df_2 = pd.DataFrame(rows_2[1:], columns = rows_2[0])

# input_text_3 = """AA abbr V36 V37 V38 V39 V40 V41 V42 V43 V44 V45 V46 V47 V48 V49 V50
# Ala A 4.35 8.249 0 0 7.3 -0.01 0 0 8.1 0 0 6 0.0373 9.69 2.34
# Arg R 4.38 8.274 0 1 11.1 0.04 1 0 10.5 1 2.45 10.76 0.0959 8.99 1.82
# Asn N 4.75 8.747 1 1 8 0.06 0 0 11.6 0 0 5.41 0.0036 8.8 2.02
# Asp D 4.76 8.41 1 0 9.2 0.15 0 1 13 -1 0 2.77 0.1263 9.6 1.88
# Cys C 4.65 8.312 0 1 14.4 0.12 0 0 5.5 0 0 5.05 0.0829 8.35 1.92
# Gln Q 4.37 8.411 0 1 10.6 0.05 0 0 10.5 0 1.25 5.65 0.0761 9.13 2.17
# Glu E 4.29 8.368 1 0 11.4 0.07 0 1 12.3 -1 1.27 3.22 0.0058 9.67 2.1
# Gly G 3.97 8.391 1 0 0 0 0 0 9 0 0 5.97 0.005 9.78 2.35
# His H 4.63 8.415 0 1 10.2 0.08 1 0 10.4 0 1.45 7.59 0.0242 9.17 1.82
# Ile I 3.95 8.195 0 0 16.1 -0.01 0 0 5.2 0 0 6.02 0 9.68 2.36
# Leu L 4.17 8.423 0 0 10.1 -0.01 0 0 4.9 0 0 5.98 0 9.6 2.36
# Lys K 4.36 8.408 0 1 10.9 0 1 0 11.3 1 3.67 9.74 0.0371 9.18 2.16
# Met M 4.52 8.418 0 1 10.4 0.04 0 0 5.7 0 0 5.74 0.0823 9.21 2.28
# Phe F 4.66 8.228 0 1 13.9 0.03 0 0 5.2 0 0 5.48 0.0946 9.18 2.16
# Pro P 4.44 0 0 0 17.8 0 0 0 8 0 0 6.3 0.0198 10.64 1.95
# Ser S 4.5 8.38 0 0 13.1 0.11 0 0 9.2 0 0 5.68 0.0829 9.21 2.19
# Thr T 4.35 8.236 0 0 16.7 0.04 0 0 8.6 0 0 5.66 0.0941 9.1 2.09
# Trp W 4.7 8.094 0 1 13.2 0 0 0 5.4 0 6.93 5.89 0.0548 9.44 2.43
# Tyr Y 4.6 8.183 0 1 13.9 0.03 0 0 6.2 0 5.06 5.66 0.0516 9.11 2.2
# Val V 3.95 8.436 0 0 17.2 0.01 0 0 5.9 0 0 5.96 0.0057 9.62 2.32
# """
# rows_3 = [line.split() for line in input_text_3.split('\n') if line]
# df_3 = pd.DataFrame(rows_3[1:], columns = rows_3[0])

# df = df_1.merge(df_2, on=['AA', 'abbr'])
# df = df.merge(df_3, on=['AA', 'abbr'])

# df.to_csv('../auxiliary_data/aminoacid_properties.csv', index=False)

# df
# Out:
#      AA abbr    V1      V2     V3   V4 V5 V6     V7   V8  ...    V41 V42 V43  \
# 0   Ala    A   7.3  -0.368   0.67  297  0  0    0.1    1  ...  -0.01   0   0
# 1   Arg    R  -3.6   -1.03   -2.1  238  4  3   1.91  2.3  ...   0.04   1   0
# 2   Asn    N  -5.7       0   -0.6  236  2  3   0.48  2.2  ...   0.06   0   0
# 3   Asp    D  -2.9    2.06   -1.2  270  1  4   0.78  6.5  ...   0.15   0   1
# 4   Cys    C  -9.2    4.53   0.38  178  0  0  -1.42  0.1  ...   0.12   0   0
# 5   Gln    Q  -0.3   0.731  -0.22  185  2  3   0.95  2.1  ...   0.05   0   0
# 6   Glu    E  -7.1    1.77  -0.76  249  1  4   0.83  6.2  ...   0.07   0   1
# 7   Gly    G  -1.2  -0.525      0  290  0  0   0.33  1.1  ...      0   0   0
# 8   His    H  -2.1       0   0.64  277  1  1   -0.5  2.8  ...   0.08   1   0
# 9   Ile    I   6.6   0.791    1.9  284  0  0  -1.13  0.8  ...  -0.01   0   0
# 10  Leu    L    20    1.07    1.9  337  0  0  -1.18  0.8  ...  -0.01   0   0
# ...

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rcParams['pdf.fonttype'] = 42
matplotlib.rcParams['ps.fonttype'] = 42

from scipy.stats import spearmanr

import sys
sys.path.append('../../src/')
from substitution_matrices import BLOSUM62

def robust_spearmanr(df_matrix1, df_matrix2, return_points=False):
    matrix1_flat = df_matrix1.values.flatten()
    matrix2_flat = df_matrix2.values.flatten()

    # they differ sometimes because two properties have a NaN
    mask1 = ~np.isnan(matrix1_flat)
    mask2 = ~np.isnan(matrix2_flat)
    mask = np.logical_and(mask1, mask2)

    matrix1_flat = matrix1_flat[mask]
    matrix2_flat = matrix2_flat[mask]

    return_value = spearmanr(matrix1_flat, matrix2_flat)
    
    if return_points:
        return_value = (return_value, (matrix1_flat, matrix2_flat))

    return return_value

AMINOACIDS = 'M F I L V W Y A G T S N Q D E H R K P'.split() # excluding C because Andreas doesn't consider it

df_blosum62 = pd.DataFrame(np.full((19, 19), np.nan), index=AMINOACIDS, columns=AMINOACIDS)
for aa1 in AMINOACIDS:
    for aa2 in AMINOACIDS:
        if aa1 == aa2:
            df_blosum62.loc[aa1, aa2] = np.nan
        else:
            df_blosum62.loc[aa1, aa2] = BLOSUM62[aa1][aa2] # negative so correlations are positive?

df_hermes_000 = pd.read_csv('../auxiliary_data/hcnn_fixed_structure/hcnn_pyrosetta_noise=0p0_marginal_matrix.csv', index_col=0)
df_hermes_000 = df_hermes_000.loc[AMINOACIDS, AMINOACIDS]
for aa1 in AMINOACIDS:
    for aa2 in AMINOACIDS:
        if aa1 == aa2:
            df_hermes_000.loc[aa1, aa2] = np.nan
        else:
            df_hermes_000.loc[aa1, aa2] = df_hermes_000.loc[aa1, aa2]

df_hermes_000_generic = pd.read_csv('../auxiliary_data/hcnn_fixed_structure/hermes_000_on_general_proteins_marginal_matrix.csv', index_col=0)
df_hermes_000_generic = df_hermes_000_generic.loc[AMINOACIDS, AMINOACIDS]
for aa1 in AMINOACIDS:
    for aa2 in AMINOACIDS:
        if aa1 == aa2:
            df_hermes_000_generic.loc[aa1, aa2] = np.nan
        else:
            df_hermes_000_generic.loc[aa1, aa2] = df_hermes_000_generic.loc[aa1, aa2]

df_AW_d = pd.read_csv('../auxiliary_data/AW_d.csv', index_col=0, sep='\t')
df_AW_d = -df_AW_d.loc[AMINOACIDS, AMINOACIDS]

hydrophobic_props = [f'V{i}' for i in range(1, 19)]
steric_props = [f'V{i}' for i in range(19, 36)]
electronic_props = [f'V{i}' for i in range(36, 51)]
props_type_dict = {
    'hydrophobic': hydrophobic_props,
    'steric': steric_props,
    'electronic': electronic_props
}
prop_types = list(props_type_dict.keys())
all_props = hydrophobic_props + steric_props + electronic_props

prop_type_colors = {
    'hydrophobic': 'black',
    'steric': 'red',
    'electronic': 'blue'
}

df_aa_prop = pd.read_csv('../auxiliary_data/aminoacid_properties.csv')
df_aa_prop = df_aa_prop.drop(columns={'AA'})
df_aa_prop = df_aa_prop.set_index('abbr')

# make a pseudo-substitution matrix for each property
props_dfs = {}
for prop in df_aa_prop.columns:
    properties = dict(zip(df_aa_prop.index.values, df_aa_prop[prop].values))
    matrix = np.full((19, 19), np.nan)
    for i, aa1 in enumerate(AMINOACIDS):
        for j, aa2 in enumerate(AMINOACIDS):
            if aa1 == aa2:
                matrix[i, j] = np.nan
            else:
                matrix[i, j] = -np.abs(properties[aa1] - properties[aa2])
    props_dfs[prop] = pd.DataFrame(matrix, index=AMINOACIDS, columns=AMINOACIDS)

model_to_dfs = {
    'hermes': df_hermes_000,
    'hermes_generic': df_hermes_000_generic,
    'AW_d': df_AW_d,
    'blosum62': df_blosum62
}

correlations = {}
correlations['hermes'] = {prop: robust_spearmanr(df_hermes_000, props_dfs[prop]) for prop in all_props}
correlations['hermes_generic'] = {prop: robust_spearmanr(df_hermes_000_generic, props_dfs[prop]) for prop in all_props}
correlations['AW_d'] = {prop: robust_spearmanr(df_AW_d, props_dfs[prop]) for prop in all_props}
correlations['blosum62'] = {prop: robust_spearmanr(df_blosum62, props_dfs[prop]) for prop in all_props}
all_models = list(correlations.keys())

model_to_pretty_name_sr = {
    'hermes': r'$\rho_{H_f}$',
    'hermes_generic': r'$\rho_{H_{gen}}$',
    'blosum62': r'$\rho_{B_{62}}$',
    'AW_d': r'$-\rho_{\mathcal{A}}$'
}

model_to_pretty_name = {
    'hermes': r'$H_f$',
    'hermes_generic': r'$H_{gen}$',
    'blosum62': r'$B_{62}$',
    'AW_d': r'$-\mathcal{A}$'
}

model_pairs = [('hermes', 'hermes_generic'), ('hermes', 'AW_d'), ('hermes', 'blosum62'), ('AW_d', 'blosum62')]

fontsize = 18

ncols = len(model_pairs)
nrows = 1
colsize = 3.7
rowsize = 3.5
fig, axs = plt.subplots(figsize=(ncols*colsize, nrows*rowsize), ncols=ncols, nrows=nrows)

for col, (m1, m2) in enumerate(model_pairs):

    ax = axs[col]

    for prop_type in prop_types:
        m1_values = [correlations[m1][prop][0] for prop in props_type_dict[prop_type]]
        m2_values = [correlations[m2][prop][0] for prop in props_type_dict[prop_type]]
        ax.scatter(m1_values, m2_values, facecolor='none', edgecolor=prop_type_colors[prop_type], marker='o', label=prop_type)

        # plot centroid
        centroid_m1 = np.mean(m1_values)
        centroid_m2 = np.mean(m2_values)
        ax.scatter(centroid_m1, centroid_m2, color=prop_type_colors[prop_type], marker='X', s=100)
    
    ax.axvline(0.0, ls='--', color='dimgrey')
    ax.axhline(0.0, ls='--', color='dimgrey')
    
    ax.set_xlabel(model_to_pretty_name_sr[m1], fontsize=fontsize)
    ax.set_ylabel(model_to_pretty_name_sr[m2], fontsize=fontsize)

    ax.tick_params(axis='both', labelsize=fontsize-4)

# set xlim and ylim of every subplot to be the same
xlims = [ax.get_xlim() for ax in axs]
ylims = [ax.get_ylim() for ax in axs]

xlim = (min([xlimm[0] for xlimm in xlims]), max([xlimm[1] for xlimm in xlims]))
ylim = (min([ylimm[0] for ylimm in ylims]), max([ylimm[1] for ylimm in ylims]))

lim = (min(xlim[0], ylim[0]), max(xlim[1], ylim[1]))

for ax in axs:
    ax.set_xlim(lim)
    ax.set_ylim(lim)
    ax.set_xticks([-0.2, 0.0, 0.2, 0.4, 0.6])
    ax.set_yticks([-0.2, 0.0, 0.2, 0.4, 0.6])
    ax.plot(lim, lim, ls=':', color='dimgrey')


plt.tight_layout()
plt.savefig('../auxiliary_data/scatterplot_vs_properties.png')
plt.savefig('../auxiliary_data/scatterplot_vs_properties.pdf')
plt.show()

# plot legend on separate figure
legend_handles = ax.get_legend_handles_labels()[0]
fig_leg = plt.figure(figsize=(8, 2))
ax_leg = fig_leg.add_subplot(111)
ax_leg.legend(handles=legend_handles, fontsize=fontsize-3, loc='center')
ax_leg.axis('off')
plt.tight_layout()
plt.savefig('../auxiliary_data/scatterplot_vs_properties__legend.png')
plt.savefig('../auxiliary_data/scatterplot_vs_properties__legend.pdf')
plt.show()

# compute correlations between matrices now, plot scatterplots

ncols = len(model_pairs)
nrows = 1
colsize = 3.7
rowsize = 3.5
fig, axs = plt.subplots(figsize=(ncols*colsize, nrows*rowsize), ncols=ncols, nrows=nrows)

for col, (m1, m2) in enumerate(model_pairs):

    ax = axs[col]

    (sr, sr_pval), (m1_values, m2_values) = robust_spearmanr(model_to_dfs[m1], model_to_dfs[m2], return_points=True)

    ax.scatter(m1_values, m2_values, color='black', alpha=0.5)
    
    ax.set_xlabel(model_to_pretty_name[m1], fontsize=fontsize)
    ax.set_ylabel(model_to_pretty_name[m2], fontsize=fontsize)

    ax.tick_params(axis='both', labelsize=fontsize-4)

    # print spearmanr in bottom right corner
    ax.text(0.02, 0.98, rf'$\rho = {sr:.2f}$', transform=ax.transAxes, fontsize=fontsize-2, ha='left', va='top')

plt.tight_layout()
plt.savefig('../auxiliary_data/scatterplot_matrices_against_each_other.png')
plt.savefig('../auxiliary_data/scatterplot_matrices_against_each_other.pdf')
plt.show()



# plot the matrices!

model_to_pretty_name_2 = {
    'hermes': r'$H_f - \overline{H_f}$',
    'hermes_generic': r'$H_{gen} - \overline{H_{gen}}$',
    'blosum62': r'$B_{62} - \overline{B_{62}}$',
    'AW_d': r'$-\mathcal{A} - \overline{-\mathcal{A}}$'
}

fontsize = 18

for col, m in enumerate(all_models):

    matrix = model_to_dfs[m].values
    matrix -= np.nanmean(matrix)

    mmin = np.nanmin(matrix)
    mmax = np.nanmax(matrix)
    vmin = min(mmin, -mmax)
    vmax = max(mmax, -mmin)

    fig = plt.figure(figsize=(6, 6))
    data = plt.imshow(matrix, cmap='coolwarm', vmin=vmin, vmax=vmax)
    plt.title(model_to_pretty_name_2[m], fontsize=fontsize+2)
    plt.xticks(np.arange(19), list(AMINOACIDS), fontsize=fontsize-2)
    plt.yticks(np.arange(19), list(AMINOACIDS), fontsize=fontsize-2)
    colorbar = fig.colorbar(data)
    colorbar.ax.tick_params(labelsize=fontsize+5)
    # colorbar.set_label(model_to_pretty_name_2[m], fontsize=fontsize+10)
    plt.tight_layout()
    plt.savefig(f'../auxiliary_data/average_matrix_{m}.png')
    plt.savefig(f'../auxiliary_data/average_matrix_{m}.pdf')
    plt.show()


# ## plot the HERMES matrices with the diagonal and the cysteine as well

# AMINOACIDS = 'C M F I L V W Y A G T S N Q D E H R K P'.split()

# df_hermes_000_full = pd.read_csv('../auxiliary_data/hcnn_fixed_structure/hcnn_pyrosetta_noise=0p0_marginal_matrix.csv', index_col=0)
# df_hermes_000_full = df_hermes_000_full.loc[AMINOACIDS, AMINOACIDS]

# df_hermes_050_full = pd.read_csv('../auxiliary_data/hcnn_fixed_structure/hcnn_pyrosetta_noise=0p5_marginal_matrix.csv', index_col=0)
# df_hermes_050_full = df_hermes_050_full.loc[AMINOACIDS, AMINOACIDS]


# for name, matrix_df in zip(['hermes_fixed_000_full', 'hermes_fixed_050_full'], [df_hermes_000_full, df_hermes_050_full]):

#     matrix = matrix_df.values
#     # matrix -= np.nanmean(matrix)

#     # mmin = np.nanmin(matrix)
#     # mmax = np.nanmax(matrix)
#     # vmin = min(mmin, -mmax)
#     # vmax = max(mmax, -mmin)

#     # print(np.nanmax(matrix))

#     from matplotlib.colors import TwoSlopeNorm

#     norm = TwoSlopeNorm(vmin=np.nanmin(matrix), vcenter=0, vmax=np.nanmax(matrix))

#     fig = plt.figure(figsize=(6, 6))
#     data = plt.imshow(matrix, cmap='coolwarm', norm=norm, interpolation='none') #, vmin=vmin, vmax=vmax)
#     # plt.title(model_to_pretty_name[m], fontsize=fontsize)
#     plt.xticks(np.arange(20), list(AMINOACIDS), fontsize=fontsize-2)
#     plt.yticks(np.arange(20), list(AMINOACIDS), fontsize=fontsize-2)
#     colorbar = fig.colorbar(data)
#     colorbar.ax.tick_params(labelsize=fontsize+5)
#     colorbar.set_label(name, fontsize=fontsize+10)
#     plt.tight_layout()
#     plt.savefig(f'../auxiliary_data/average_matrix_{name}.png')
#     plt.savefig(f'../auxiliary_data/average_matrix_{name}.pdf')
#     plt.show()
# Out:
# posx and posy should be finite values

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors

# Generate some random data (5 rows, 4 columns)
data = np.random.rand(5, 4)

def custom_colormap():
    return mcolors.LinearSegmentedColormap.from_list("custom_cmap", ["white", plt.get_cmap('tab20').colors[3]])

# Define different colormaps for each column
colormaps = [custom_colormap(), 'Blues', 'Greens', 'Purples']

# Create a figure and axis
fig, ax = plt.subplots()

# Get the number of rows and columns
n_rows, n_cols = data.shape

# Define x and y coordinates for pcolormesh
x = np.arange(n_cols + 1)
y = np.arange(n_rows + 1)

# Normalize data
norm = mcolors.Normalize(vmin=np.min(data), vmax=np.max(data))

# Plot each column separately
for i in range(n_cols):
    
    # Create a colormap
    cmap = plt.get_cmap(colormaps[i])
    
    # Create a mesh grid for this column (taking one slice of x at a time)
    X, Y = np.meshgrid(x[i:i+2], y)
    
    # Plot the column using the correct shape
    ax.pcolormesh(X, Y, data[:, i].reshape(-1, 1), cmap=cmap, norm=norm)

# Adjust the axis
ax.set_xticks(np.arange(n_cols) + 0.5)
ax.set_xticklabels([f'Col {i}' for i in range(n_cols)])
ax.set_yticks(np.arange(n_rows) + 0.5)
ax.set_yticklabels([f'Row {i}' for i in range(n_rows)])
ax.set_title("Heatmap with Different Colormaps per Column")

plt.show()
